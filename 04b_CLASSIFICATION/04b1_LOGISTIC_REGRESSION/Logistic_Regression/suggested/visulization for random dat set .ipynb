# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.metrics import log_loss

# %%
# Generate dataset
X, y = make_classification(n_samples=200, n_features=1, n_informative=1,
                           n_redundant=0, n_clusters_per_class=1, random_state=42)

# %%
# Fit logistic regression
model = LogisticRegression(max_iter=200)
model.fit(X, y)
# Out:
# LogisticRegression(max_iter=200)

# %%
# Predict probabilities
probs = model.predict_proba(X)[:, 1]

# %%
# Calculate cross-entropy loss
loss = log_loss(y, probs)
print("Cross-Entropy Loss:", loss)
# Out:
# Cross-Entropy Loss: 0.08917644622761506

# %%
# Sigmoid curve (predicted probability)
plt.plot(X, probs, label='Predicted Probability (Sigmoid)', color='red')
plt.legend()
plt.xlabel("Features of X")
plt.ylabel("prob.")
plt.grid(True)

# %%
# Scatter plot of true labels
plt.scatter(X_sorted, y_sorted, label='True Labels', color='red', alpha=0.5)

# %%
# How my data look like?

# %%
# Add small noise to y for visualization
y_jitter = y + np.random.normal(0, 0.05, size=len(y))

plt.figure()
plt.scatter(X[:, 0], y_jitter)
plt.xlabel("Feature value (X)")
plt.ylabel("Class (with jitter)")
plt.title("1D Classification Data Visualization")
plt.show()

# %% [markdown]
# # adding Random Noise

# %%
plt.figure()
plt.scatter(X[:, 0],y)
plt.xlabel("Feature value (X)")
plt.ylabel("Class (with jitter)")
plt.title("1D Classification Data Visualization")
plt.show()

# %% [markdown]
# # Now my data is look like This and the we can fit the equation of the straight line over there

# %% [markdown]
# # so we use the polynomial curve espacilly sigmoid function to cover maximum Data points
