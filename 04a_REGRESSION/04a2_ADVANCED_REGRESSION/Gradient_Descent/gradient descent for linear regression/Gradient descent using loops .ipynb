# %% [markdown]
# # Gradient descent using loops

# %%
import numpy as np
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=10, n_features=1 , n_informative=1, n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %% [markdown]
# # Using ordinary least sqaure method to find the the coff or it also called slope¶

# %%
#OLs 
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([48.53048884])

# %%
reg.intercept_
# Out:
# -18.45167109876422

# %%
# plotting the inital graph 
# now how our regression like look like 
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color ='red')

# %%
# assign Values 
# let assume b=100
b=100 
m =78.35 # slope
lr = 0.01 # learning rate 
epoches = 100  # final limit of steps

# %%
# changing diffrent types of parameter 
epchoes =100
lr = 0.01
for i in range(epoches):
    loss_slope = -2 *np.sum(y-m * X.ravel() -b )
    step_size = loss_slope * lr
    b = b - step_size 
    y_pred = m * X + b
    plt.plot(X,y_pred)
plt.scatter(X,y)
