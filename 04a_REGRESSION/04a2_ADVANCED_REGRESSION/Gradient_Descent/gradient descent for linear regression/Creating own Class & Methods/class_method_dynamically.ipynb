# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=5,random_state=2)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
# finding the slope and intercept
m = lr.coef_
b = lr.intercept_

# %%
print(m)
print(b)
# Out:
# [60.16282683]
# 0.13335980984725015

# %%
m =60.133

# %%
class GDRegressor:
    def __init__(self, learning_rate, epochs):
        self.m = 98.08   # initial slope
        self.b = 120     # initial intercept
        self.lr = learning_rate
        self.epochs = epochs
    def fit(self, X, y):
        for i in range(self.epochs):
             loss_slope = -2 * np.sum(y - self.m * X.ravel() - self.b)
             self.b = self.b - (self.lr * loss_slope)
             print(loss_slope,self.b)
        print(self.b)

# %%
gd= GDRegressor(0.01, 10000)

# %%
gd.fit(X,y)
# Out:
# 23186.613930453812 -111.86613930453814
# -23186.613930453823 120.00000000000009
# 23186.613930453826 -111.8661393045382
# -23186.613930453834 120.00000000000014
# 23186.61393045384 -111.86613930453828
# -23186.61393045385 120.0000000000002
# 23186.61393045385 -111.86613930453828
# -23186.61393045385 120.0000000000002
# 23186.61393045385 -111.86613930453828
# -23186.61393045385 120.0000000000002
# 23186.61393045385 -111.86613930453828
# -23186.61393045385 120.0000000000002
# 23186.61393045385 -111.86613930453828
# -23186.61393045385 120.0000000000002
# 23186.61393045385 -111.86613930453828
# -23186.61393045385 120.0000000000002
# 23186.61393045385 -111.86613930453828
# -23186.61393045385 120.0000000000002
# 23186.61393045385 -111.86613930453828
# -23186.61393045385 120.0000000000002
# 23186.61393045385 -111.86613930453828
# -23186.61393045385 120.0000000000002
# 23186.61393045385 -111.86613930453828
# -23186.61393045385 120.0000000000002
# 23186.61393045385 -111.86613930453828
# ...
